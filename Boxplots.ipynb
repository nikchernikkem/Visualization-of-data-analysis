# %%
import numpy as np
import pandas as pd
from plotly import graph_objects as go
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## TEST Ln_perm - poro - BAR

# %%
path=''
File_name = 'data_boxplot.xlsx'
df = pd.read_excel(path + File_name, sheet_name='k_phi_BAR')
df
# Out:
#           phi         k      ln_k     Trend
# 0    0.225396   86.2250  4.456960  4.738936
# 1    0.227929   85.8410  4.452497  4.831708
# 2    0.228233   92.4900  4.527101  4.842835
# 3    0.232230  105.5893  4.659557  4.989246
# 4    0.223823   89.8120  4.497719  4.681312
# ..        ...       ...       ...       ...
# 188  0.221092  127.8270  4.850678  4.581283
# 189  0.223609  149.4400  5.006895  4.673468
# 190  0.220259  125.1560  4.829561  4.550762
# 191  0.223380  130.0750  4.868111  4.665084
# 192  0.211542  112.8070  4.725678  4.231458
#
# [193 rows x 4 columns]

# %%
# df = px.data.tips()
fig = px.box(df, y="ln_k")
# fig = px.box(df, y="ln_k", points="all")
fig.update_layout(autosize=False,width=750,height=700,margin=dict(l=50,r=50,b=50,t=50,pad=4),paper_bgcolor="White", plot_bgcolor="White")
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.show()

# %%
y0 = df['ln_k']
y1 = df['Trend']

fig = go.Figure()
fig.add_trace(go.Box(y=y0, quartilemethod="exclusive", name='ln(k)_exc'))
fig.add_trace(go.Box(y=y0, quartilemethod="linear", name='ln(k)_lin'))
fig.add_trace(go.Box(y=y0, quartilemethod="inclusive", name='ln(k)_inc'))
fig.add_trace(go.Box(y=y1, name='trend'))

fig.update_layout(autosize=False,width=750,height=700,margin=dict(l=50,r=50,b=50,t=50,pad=4),paper_bgcolor="White", plot_bgcolor="White")
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')

fig.show()

# %% [markdown]
# ## Все скважины

# %%
path=''
File_name = 'данные_керн.xlsx'
R1 = pd.read_excel(path + File_name, sheet_name='1')
R2 = pd.read_excel(path + File_name, sheet_name='2')
R3 = pd.read_excel(path + File_name, sheet_name='3')
R4 = pd.read_excel(path + File_name, sheet_name='4')
ALL = pd.read_excel(path + File_name, sheet_name='ALL_WELLS')
No_Zero = pd.read_excel(path + File_name, sheet_name='No Zero')
Correct = pd.read_excel(path + File_name, sheet_name='Correct')

# %%
y0 = ALL['phi']
# y1 = R2['phi']
# y2 = R3['phi']
# y3 = R4['phi']
fig = go.Figure()
fig.add_trace(go.Box(y=y0, name='', marker_color = 'orange', boxmean='sd'))
# fig.add_trace(go.Box(y=y1, name='Скважина R2', marker_color = 'blue', boxmean='sd'))
# fig.add_trace(go.Box(y=y2, name='Скважина R3', marker_color = 'green', boxmean='sd'))
# fig.add_trace(go.Box(y=y3, name='Скважина R4', marker_color = 'red', boxmean='sd'))

# fig.update_yaxes(title_text="Пористость, д.е.", titlefont=dict(family="arial",size=18,color="black"))
fig.update_layout(title="Пористость, д.е.", title_x = 0.5, titlefont=dict(family="arial",size=23,color="black") ,autosize=False,width=750,height=700,margin=dict(l=50,r=50,b=50,t=50,pad=4),paper_bgcolor="White", plot_bgcolor="White")
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray', tickfont=dict(family='Arial', color='black', size=18))

fig.update_layout(showlegend=False)

fig.show()

#fig.write_image("C:/Users/ShirokovAV/Desktop/python/images/poro_box.png")

# %%
y0 = ALL['LNk']
# y1 = R2['phi']
# y2 = R3['phi']
# y3 = R4['phi']
fig = go.Figure()
fig.add_trace(go.Box(y=y0, name='', marker_color = 'blue', boxmean='sd'))
# fig.add_trace(go.Box(y=y1, name='Скважина R2', marker_color = 'blue', boxmean='sd'))
# fig.add_trace(go.Box(y=y2, name='Скважина R3', marker_color = 'green', boxmean='sd'))
# fig.add_trace(go.Box(y=y3, name='Скважина R4', marker_color = 'red', boxmean='sd'))

# fig.update_yaxes(title_text="Пористость, д.е.", titlefont=dict(family="arial",size=18,color="black"))
fig.update_layout(title="Логарифм проницаемости", title_x = 0.5, titlefont=dict(family="arial",size=23,color="black") ,autosize=False,width=750,height=700,margin=dict(l=50,r=50,b=50,t=50,pad=4),paper_bgcolor="White", plot_bgcolor="White")
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray', tickfont=dict(family='Arial', color='black', size=18))

fig.update_layout(showlegend=False)

fig.show()

#fig.write_image("C:/Users/ShirokovAV/Desktop/python/images/poro_box.png")

# %%
y0 = ALL['плотность']
# y1 = R2['phi']
# y2 = R3['phi']
# y3 = R4['phi']
fig = go.Figure()
fig.add_trace(go.Box(y=y0, name='', marker_color = 'green', boxmean='sd'))
# fig.add_trace(go.Box(y=y1, name='Скважина R2', marker_color = 'blue', boxmean='sd'))
# fig.add_trace(go.Box(y=y2, name='Скважина R3', marker_color = 'green', boxmean='sd'))
# fig.add_trace(go.Box(y=y3, name='Скважина R4', marker_color = 'red', boxmean='sd'))

# fig.update_yaxes(title_text="Пористость, д.е.", titlefont=dict(family="arial",size=18,color="black"))
fig.update_layout(title="Плотность, г/см\u00b3", title_x = 0.5, titlefont=dict(family="arial",size=23,color="black") ,autosize=False,width=750,height=700,margin=dict(l=50,r=50,b=50,t=50,pad=4),paper_bgcolor="White", plot_bgcolor="White")
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray', tickfont=dict(family='Arial', color='black', size=18))

fig.update_layout(showlegend=False)

fig.show()

#fig.write_image("C:/Users/ShirokovAV/Desktop/python/images/poro_box.png")

# %%
y0 = ALL['Swc']
# y1 = R2['phi']
# y2 = R3['phi']
# y3 = R4['phi']
fig = go.Figure()
fig.add_trace(go.Box(y=y0, name='', marker_color = 'red', boxmean='sd'))
# fig.add_trace(go.Box(y=y1, name='Скважина R2', marker_color = 'blue', boxmean='sd'))
# fig.add_trace(go.Box(y=y2, name='Скважина R3', marker_color = 'green', boxmean='sd'))
# fig.add_trace(go.Box(y=y3, name='Скважина R4', marker_color = 'red', boxmean='sd'))

# fig.update_yaxes(title_text="Пористость, д.е.", titlefont=dict(family="arial",size=18,color="black"))
fig.update_layout(title="Остататочная водонасыщенность, д.е.", title_x = 0.5, titlefont=dict(family="arial",size=23,color="black") ,autosize=False,width=750,height=700,margin=dict(l=50,r=50,b=50,t=50,pad=4),paper_bgcolor="White", plot_bgcolor="White")
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray', tickfont=dict(family='Arial', color='black', size=18))

fig.update_layout(showlegend=False)

fig.show()

#fig.write_image("C:/Users/ShirokovAV/Desktop/python/images/poro_box.png")

# %%
y0 = No_Zero['Swc']
# y1 = R2['phi']
# y2 = R3['phi']
# y3 = R4['phi']
fig = go.Figure()
fig.add_trace(go.Box(y=y0, name='', marker_color = 'red', boxmean='sd'))
# fig.add_trace(go.Box(y=y1, name='Скважина R2', marker_color = 'blue', boxmean='sd'))
# fig.add_trace(go.Box(y=y2, name='Скважина R3', marker_color = 'green', boxmean='sd'))
# fig.add_trace(go.Box(y=y3, name='Скважина R4', marker_color = 'red', boxmean='sd'))

# fig.update_yaxes(title_text="Пористость, д.е.", titlefont=dict(family="arial",size=18,color="black"))
fig.update_layout(title="Остататочная водонасыщенность, д.е.", title_x = 0.5, titlefont=dict(family="arial",size=23,color="black") ,autosize=False,width=750,height=700,margin=dict(l=50,r=50,b=50,t=50,pad=4),paper_bgcolor="White", plot_bgcolor="White")
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray', tickfont=dict(family='Arial', color='black', size=18))

fig.update_layout(showlegend=False)

fig.show()

#fig.write_image("C:/Users/ShirokovAV/Desktop/python/images/poro_box.png")

# %%
Correct = pd.read_excel(path + File_name, sheet_name='Correct (2)')
y0 = Correct['Swc']
# y1 = R2['phi']
# y2 = R3['phi']
# y3 = R4['phi']
fig = go.Figure()
fig.add_trace(go.Box(y=y0, name='', marker_color = 'red', boxmean='sd'))
# fig.add_trace(go.Box(y=y1, name='Скважина R2', marker_color = 'blue', boxmean='sd'))
# fig.add_trace(go.Box(y=y2, name='Скважина R3', marker_color = 'green', boxmean='sd'))
# fig.add_trace(go.Box(y=y3, name='Скважина R4', marker_color = 'red', boxmean='sd'))

# fig.update_yaxes(title_text="Пористость, д.е.", titlefont=dict(family="arial",size=18,color="black"))
fig.update_layout(title="Остататочная водонасыщенность, д.е.", title_x = 0.5, titlefont=dict(family="arial",size=23,color="black") ,autosize=False,width=750,height=700,margin=dict(l=50,r=50,b=50,t=50,pad=4),paper_bgcolor="White", plot_bgcolor="White")
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray', tickfont=dict(family='Arial', color='black', size=18))

fig.update_layout(showlegend=False)

fig.show()

#fig.write_image("C:/Users/ShirokovAV/Desktop/python/images/poro_box.png")

# %% [markdown]
# ## Целевой

# %%
path=''
File_name = 'данные_керн.xlsx'
R1 = pd.read_excel(path + File_name, sheet_name='1')
R2 = pd.read_excel(path + File_name, sheet_name='2')
R3 = pd.read_excel(path + File_name, sheet_name='3')
R4 = pd.read_excel(path + File_name, sheet_name='4')
ALL = pd.read_excel(path + File_name, sheet_name='4')

# %%
y0 = ALL['LNk']
# y1 = R2['phi']
# y2 = R3['phi']
# y3 = R4['phi']
fig = go.Figure()
fig.add_trace(go.Box(y=y0, name='', marker_color = 'orange', boxmean='sd'))
# fig.add_trace(go.Box(y=y1, name='Скважина R2', marker_color = 'blue', boxmean='sd'))
# fig.add_trace(go.Box(y=y2, name='Скважина R3', marker_color = 'green', boxmean='sd'))
# fig.add_trace(go.Box(y=y3, name='Скважина R4', marker_color = 'red', boxmean='sd'))

# fig.update_yaxes(title_text="Пористость, д.е.", titlefont=dict(family="arial",size=18,color="black"))
fig.update_layout(title="Пористость, д.е.", title_x = 0.5, titlefont=dict(family="arial",size=23,color="black") ,autosize=False,width=750,height=700,margin=dict(l=50,r=50,b=50,t=50,pad=4),paper_bgcolor="White", plot_bgcolor="White")
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray', tickfont=dict(family='Arial', color='black', size=18))

fig.update_layout(showlegend=False)

fig.show()

#fig.write_image("C:/Users/ShirokovAV/Desktop/python/images/poro_box.png")

# %%
y0 = R1['phi']
y1 = R2['phi']
y2 = R3['phi']
y3 = R4['phi']
fig = go.Figure()
fig.add_trace(go.Box(y=y0, name='Скважина R1', marker_color = 'orange', boxmean='sd'))
fig.add_trace(go.Box(y=y1, name='Скважина R2', marker_color = 'blue', boxmean='sd'))
fig.add_trace(go.Box(y=y1, name='Скважина R3', marker_color = 'green', boxmean='sd'))
fig.add_trace(go.Box(y=y2, name='Скважина R4', marker_color = 'red', boxmean='sd')

# fig.update_yaxes(title_text="Пористость, д.е.", titlefont=dict(family="arial",size=18,color="black"))
fig.update_layout(title="Пористость, д.е.", title_x = 0.5, titlefont=dict(family="arial",size=18,color="black") ,autosize=False,width=750,height=700,margin=dict(l=50,r=50,b=50,t=50,pad=4),paper_bgcolor="White", plot_bgcolor="White")
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')

fig.update_layout(showlegend=False)

fig.show()

#fig.write_image("C:/Users/ShirokovAV/Desktop/python/images/poro_box.png")

# %%
path=''
File_name = 'data_boxplot.xlsx'
df = pd.read_excel(path + File_name, sheet_name='perm')
df
# Out:
#            R1        R2        R3        R4
# 0    5.560093  0.176471  3.900173  5.253121
# 1    5.611389  2.055405  3.713304       NaN
# 2    5.627675  1.363537       NaN  5.340016
# 3         NaN  0.893227  4.201643       NaN
# 4    5.594280  1.798901  3.867486  5.365635
# ..        ...       ...       ...       ...
# 428  5.354849       NaN       NaN       NaN
# 429  5.421238       NaN       NaN       NaN
# 430       NaN       NaN       NaN       NaN
# 431  0.872548       NaN       NaN       NaN
# 432  0.860778       NaN       NaN       NaN
#
# [433 rows x 4 columns]

# %%
y0 = R1['LNk']
y1 = R2['LNk']
y2 = R3['LNk']
y3 = R4['LNk']
fig = go.Figure()
fig.add_trace(go.Box(y=y0, name='Скважина R1', marker_color = 'orange', boxmean='sd'))
fig.add_trace(go.Box(y=y1, name='Скважина R2', marker_color = 'blue', boxmean='sd'))
fig.add_trace(go.Box(y=y2, name='Скважина R3', marker_color = 'green', boxmean='sd'))
fig.add_trace(go.Box(y=y3, name='Скважина R4', marker_color = 'red', boxmean='sd'))

# fig.update_yaxes(title_text="Пористость, д.е.", titlefont=dict(family="arial",size=18,color="black"))
fig.update_layout(title="Логарифм проницаемости", title_x = 0.5, titlefont=dict(family="arial",size=18,color="black") ,autosize=False,width=750,height=700,margin=dict(l=50,r=50,b=50,t=50,pad=4),paper_bgcolor="White", plot_bgcolor="White")
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')

fig.update_layout(showlegend=False)

fig.show()

# fig.write_image("C:/Users/ShirokovAV/Desktop/python/images/perm_box.png")

# %%
path=''
File_name = 'data_boxplot.xlsx'
df = pd.read_excel(path + File_name, sheet_name='ro')
df
# Out:
#            R1        R3        R4
# 0    2.053950       NaN  2.027167
# 1    2.054265       NaN       NaN
# 2    2.387033       NaN  2.020732
# 3         NaN  2.060808       NaN
# 4         NaN  2.083692  2.026368
# ..        ...       ...       ...
# 806  2.001927       NaN       NaN
# 807  2.191403       NaN       NaN
# 808  2.189675       NaN       NaN
# 809  2.191403       NaN       NaN
# 810  2.189675       NaN       NaN
#
# [811 rows x 3 columns]

# %%
y0 = R1['плотность']
y1 = R3['плотность']
y2 = R4['плотность']
# y3 = df['R2']
fig = go.Figure()
fig.add_trace(go.Box(y=y0, name='Скважина R1', marker_color = 'orange', boxmean='sd'))
# fig.add_trace(go.Box(y=y3, name='Скважина R2', marker_color = 'blue', boxmean='sd'))
fig.add_trace(go.Box(y=y1, name='Скважина R3', marker_color = 'green', boxmean='sd'))
fig.add_trace(go.Box(y=y2, name='Скважина R4', marker_color = 'red', boxmean='sd'))

# fig.update_yaxes(title_text="Пористость, д.е.", titlefont=dict(family="arial",size=18,color="black"))
fig.update_layout(title="Плотность, г/см\u00b3", title_x = 0.5, titlefont=dict(family="arial",size=18,color="black") ,autosize=False,width=750,height=700,margin=dict(l=50,r=50,b=50,t=50,pad=4),paper_bgcolor="White", plot_bgcolor="White")
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')

fig.update_layout(showlegend=False)

fig.show()

# fig.write_image("C:/Users/ShirokovAV/Desktop/python/images/ro_box.png")

# %%
path=''
File_name = 'data_boxplot.xlsx'
df = pd.read_excel(path + File_name, sheet_name='Sw')
df
# Out:
#            R1        R2        R3        R4
# 0         NaN  0.821888  0.231243       NaN
# 1         NaN  0.714922  0.243388       NaN
# 2    0.644279  0.775174       NaN       NaN
# 3         NaN  0.781581  0.338486       NaN
# 4         NaN  0.756439  0.355574  0.189695
# ..        ...       ...       ...       ...
# 806       NaN       NaN       NaN       NaN
# 807  0.542649       NaN       NaN       NaN
# 808  0.485431       NaN       NaN       NaN
# 809  0.542649       NaN       NaN       NaN
# 810  0.485431       NaN       NaN       NaN
#
# [811 rows x 4 columns]

# %%
y0 = R1['Swc']
y1 = R2['Swc']
y2 = R3['Swc']
y3 = R4['Swc']
fig = go.Figure()
fig.add_trace(go.Box(y=y0, name='Скважина R1', marker_color = 'orange', boxmean='sd'))
fig.add_trace(go.Box(y=y1, name='Скважина R2', marker_color = 'blue', boxmean='sd'))
fig.add_trace(go.Box(y=y2, name='Скважина R3', marker_color = 'green', boxmean='sd'))
fig.add_trace(go.Box(y=y3, name='Скважина R4', marker_color = 'red', boxmean='sd'))

# fig.update_yaxes(title_text="Пористость, д.е.", titlefont=dict(family="arial",size=18,color="black"))
fig.update_layout(title="Остататочная водонасыщенность, д.е.", title_x = 0.5, titlefont=dict(family="arial",size=18,color="black") ,autosize=False,width=750,height=700,margin=dict(l=50,r=50,b=50,t=50,pad=4),paper_bgcolor="White", plot_bgcolor="White")
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', gridcolor='lightgray')

fig.update_layout(showlegend=False)

fig.show()

# fig.write_image("C:/Users/ShirokovAV/Desktop/python/images/Sw_box.png")
