# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_1 = pd.read_excel('Vsh.xlsx', header = 0, sheet_name ='R1-4 0') #header = 0 строка заголовков
data_2 = pd.read_excel('Vsh.xlsx', header = 0, sheet_name = 'R3-4 1') 
data_3 = pd.read_excel('Vsh.xlsx', header = 0, sheet_name = 'R1-4') 
data_4 = pd.read_excel('Vsh_Корр_2.xlsx', header = 0, sheet_name = 'R1-4-3 0') 
data_5 = pd.read_excel('Vsh_Корр_2.xlsx', header = 0, sheet_name = 'R1-4-3 1')

# %%
def calculate_rgb(
    rgb: tuple((int, int, int)),
    opacity: float,
) -> [float, float, float, float]:
    """
    Функция получает на вход RGB палитру в виде чисел 0-255, а также уровень непрозрачности в диапазоне 0-1.
    Возвращает список из четырех чисел. Первые три числа - RGB, пересчитанные для seaborn. Последнее число - уровень непрозрачности.
    """
    return [i/255 for i in rgb] + [opacity]

def make_palette(
    rgb_tuple: tuple((int, int, int)),
    opacity_tuple: tuple((float, float)),
    elem_numbers: int,
) -> [list]:
    """
    Функция получает на вход числа RGB, диапазон непрозрачности и количество элементов, которые нужно сгенерировать.
    Возвращает список элементов (списков) согласно задааному количеству элементов.
    """
    return [calculate_rgb(rgb_tuple, o) for o in np.linspace(opacity_tuple[0], opacity_tuple[1], elem_numbers)]

# %%
# make_palette((R, G, B), (opacity_max, opacity_min), element_numbers)
own_palette = make_palette((0, 156, 222), (1.0, 1.0), 1)

# %%
palette = ["#009cde"]

# %%
with sns.axes_style("whitegrid"):
    s = sns.histplot(
        data_4['Vsh'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(180/5), line_kws = {'linewidth': 3}, color="orange"
    )
    ss = sns.histplot(
        data_5['Vsh'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(180/5), line_kws = {'linewidth': 3}, palette=sns.color_palette(palette, 1),
    )
#plt.xticks([0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95,1.0])
sns.set_theme(rc={'figure.figsize':(10,5)}, style = "darkgrid")
s.set_xlabel("Глинистость, д.е.", fontsize = 18, family='Arial')
s.set_ylabel("Частота", fontsize = 18, family='Arial')
ss.set_xlabel("Глинистость, д.е", fontsize = 18, family='Arial')
ss.set_ylabel("Частота", fontsize = 18, family='Arial')
ss.set(xlim=(-0.05, 1))
# Out:
# C:\Users\nik_c\AppData\Local\Temp\ipykernel_10620\274671041.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ss = sns.histplot(
# [(-0.05, 1.0)]

# %%
R1 = pd.read_excel('данные_керн.xlsx', header = 0, sheet_name = '1') 
R2 = pd.read_excel('данные_керн.xlsx', header = 0, sheet_name = '2') 
R3 = pd.read_excel('данные_керн.xlsx', header = 0, sheet_name = '3') 
R4 = pd.read_excel('данные_керн.xlsx', header = 0, sheet_name = '4') 
R3_1 = pd.read_excel('данные_керн.xlsx', header = 0, sheet_name = '3 (1)') 
R3_2 = pd.read_excel('данные_керн.xlsx', header = 0, sheet_name = '3 (2)') 
R3_3 = pd.read_excel('данные_керн.xlsx', header = 0, sheet_name = '3 (3)') 
All = pd.read_excel('Все скважины коллектор.xlsx', header = 0, sheet_name = 'Sheet1')

# %% [markdown]
# ## Поро

# %%
palette_ = ["orange", 'blue', 'green', 'red']

# %%
with sns.axes_style("whitegrid"):
    bb = sns.histplot(
        data= All, hue = 'Скв', x='LNk', kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=100, line_kws = {'linewidth': 3}, palette = palette_)
sns.set(font_scale = 1.5)
sns.set_theme(rc={'figure.figsize':(10,5)}, style = "darkgrid")
bb.set_xlabel("Логарифм проницаемости", fontsize = 15, family='Arial')
bb.set_ylabel("Частота", fontsize = 15, family='Arial')
bb.set(xlim=(0.16, None))
bb.set_title('Скважины R1, R2, R3, R4', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Скважины R1, R2, R3, R4')

# %%
with sns.axes_style("whitegrid"):
    bb = sns.histplot(
        data= All, x='LNk', kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=100, line_kws = {'linewidth': 3}, palette = palette_)
sns.set(font_scale = 1.5)
sns.set_theme(rc={'figure.figsize':(10,5)}, style = "darkgrid")
bb.set_xlabel("Логарифм проницаемости", fontsize = 15, family='Arial')
bb.set_ylabel("Частота", fontsize = 15, family='Arial')
bb.set(xlim=(0.16, None))
bb.set_title('Скважины R1, R2, R3, R4', fontsize = 18)
# Out:
# C:\Users\nik_c\AppData\Local\Temp\ipykernel_15872\3312029101.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   bb = sns.histplot(
# Text(0.5, 1.0, 'Скважины R1, R2, R3, R4')

# %%
import math
import numpy as np
from scipy. stats import lognorm
import statsmodels.api as sm
import matplotlib.pyplot as plt

#create Q-Q plot with 45-degree line added to plot
fig = sm. qqplot (R4['phi'], line='45')

plt.show()

# %%
from scipy.stats import kstest

#perform Kolmogorov-Smirnov test for normality
kstest(R4['phi'], 'norm')
# Out:
# KstestResult(statistic=0.5656093578905474, pvalue=8.537449186470514e-85, statistic_location=0.18345073987441893, statistic_sign=-1)

# %%
from scipy.stats import shapiro 
from scipy. stats import lognorm

#perform Shapiro-Wilk test for normality
shapiro(R4['phi'])
# Out:
# ShapiroResult(statistic=0.8303329944610596, pvalue=8.496815795756951e-17)

# %%
with sns.axes_style("whitegrid"):
    d = sns.histplot(
        R1['phi'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(25), line_kws = {'linewidth': 3}, color="orange"
    )
sns.set(font_scale = 1.5)
sns.set_theme(rc={'figure.figsize':(10,5)}, style = "darkgrid")
d.set_xlabel("Пористость, д.е.", fontsize = 15, family='Arial')
d.set_ylabel("Частота", fontsize = 15, family='Arial')
d.set(xlim=(0.075, None))
d.set_title('R1', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'R1')

# %%
with sns.axes_style("whitegrid"):
    c = sns.histplot(
        R2['phi'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(10), line_kws = {'linewidth': 3}, color="blue"
)
c.set_xlabel("Пористость, д.е.", fontsize = 15, family='Arial')
c.set_ylabel("Частота", fontsize = 15, family='Arial')
sns.set_theme(rc={'figure.figsize':(10,5)}, style = "darkgrid")
#c.set(xlim=(0.227, 0.241))
c.set_title('R2', fontsize = 18)
sns.set(font_scale = 1.5)

# %%
with sns.axes_style("whitegrid"):
    b = sns.histplot(
        R3['phi'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(25), line_kws = {'linewidth': 3}, color="green"
    )
sns.set_theme(rc={'figure.figsize':(10,5)})
b.set(xlim=(0.15, 0.25))
b.set_title('R3', fontsize = 18)
b.set_xlabel("Пористость, д.е.", fontsize = 15, family='Arial')
b.set_ylabel("Частота", fontsize = 15, family='Arial')
sns.set(font_scale = 1.5)

# %%
bb = sns.histplot(
    data= R3_3, hue = 'Deposition', x='phi', kde=True,
    stat="density", kde_kws=dict(cut=2),
    alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(180/5), line_kws = {'linewidth': 3}, color="green"
)
bb.set_xlabel("Porosity", fontsize = 15)
bb.set_ylabel("Density", fontsize = 15)
sns.set_theme(rc={'figure.figsize':(10,5)})
bb.set(xlim=(0.15, 0.25))
bb.set_title('R3', fontsize = 18)
sns.set(font_scale = 1.5)

# %%
with sns.axes_style("whitegrid"):
    a = sns.histplot(
        R4['phi'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(180/5), line_kws = {'linewidth': 3}, color="red"
)
a.set_xlabel("Пористость, д.е.", fontsize = 15, family='Arial')
a.set_ylabel("Частота", fontsize = 15, family='Arial')
sns.set_theme(rc={'figure.figsize':(10,5)})
a.set(xlim=(0.07, 0.26))
a.set_title('R4', fontsize = 18, family='Arial')
sns.set(font_scale = 1.5)

# %% [markdown]
# ## Perm

# %%
with sns.axes_style("whitegrid"):
    a1 = sns.histplot(
        R1['perm'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(180/5), line_kws = {'linewidth': 3}, color="orange"
)
a1.set_xlabel("Проницаемость, д.е.", fontsize = 15, family='Arial')
a1.set_ylabel("Частота", fontsize = 15, family='Arial')
sns.set_theme(rc={'figure.figsize':(10,5)})
a1.set(xlim=(0, None))
a1.set_title('R1', fontsize = 18)
sns.set(font_scale = 1.5)

# %%
with sns.axes_style("whitegrid"):
    a2 = sns.histplot(
        R2['perm'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(10), line_kws = {'linewidth': 3}, color="blue"
)
a2.set_xlabel("Проницаемость, д.е.", fontsize = 15, family='Arial')
a2.set_ylabel("Частота", fontsize = 15, family='Arial')
sns.set_theme(rc={'figure.figsize':(10,5)})
a2.set(xlim=(0, None))
a2.set_title('R2', fontsize = 18)
sns.set(font_scale = 1.5)

# %%
with sns.axes_style("whitegrid"):
    a3 = sns.histplot(
        R3['perm'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(180/5), line_kws = {'linewidth': 3}, color="green"
)
a3.set_xlabel("Проницаемость, д.е.", fontsize = 15, family='Arial')
a3.set_ylabel("Частота", fontsize = 15, family='Arial')
sns.set_theme(rc={'figure.figsize':(10,5)})
a3.set(xlim=(0, None))
a3.set_title('R3', fontsize = 18)
sns.set(font_scale = 1.5)

# %%
with sns.axes_style("whitegrid"):
    a4 = sns.histplot(
        R4['perm'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(180/5), line_kws = {'linewidth': 3}, color="red"
)
a4.set_xlabel("Проницаемость, д.е.", fontsize = 15, family='Arial')
a4.set_ylabel("Частота", fontsize = 15, family='Arial')
sns.set_theme(rc={'figure.figsize':(10,5)})
a4.set(xlim=(0, None))
a4.set_title('R4', fontsize = 18)
sns.set(font_scale = 1.5)

# %% [markdown]
# ## От логарифма

# %%
with sns.axes_style("whitegrid"):
    a1 = sns.histplot(
        R1['LNk'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(180/5), line_kws = {'linewidth': 3}, color="orange"
)
a1.set_xlabel("Логарифм проницаемости", fontsize = 15, family='Arial')
a1.set_ylabel("Частота", fontsize = 15, family='Arial')
sns.set_theme(rc={'figure.figsize':(10,5)})
a1.set(xlim=(0, None))
a1.set_title('R1', fontsize = 18)
sns.set(font_scale = 1.5)

# %%
with sns.axes_style("whitegrid"):
    a2 = sns.histplot(
        R2['LNk'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(10), line_kws = {'linewidth': 3}, color="blue"
)
a2.set_xlabel("Логарифм проницаемости", fontsize = 15, family='Arial')
a2.set_ylabel("Частота", fontsize = 15, family='Arial')
sns.set_theme(rc={'figure.figsize':(10,5)})
a2.set(xlim=(0, None))
a2.set_title('R2', fontsize = 18)
sns.set(font_scale = 1.5)

# %%
with sns.axes_style("whitegrid"):
    a3 = sns.histplot(
        R3['LNk'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(180/5), line_kws = {'linewidth': 3}, color="green"
)
a3.set_xlabel("Логарифм проницаемости", fontsize = 15, family='Arial')
a3.set_ylabel("Частота", fontsize = 15, family='Arial')
sns.set_theme(rc={'figure.figsize':(10,5)})
a3.set(xlim=(0, None))
a3.set_title('R3', fontsize = 18)
sns.set(font_scale = 1.5)

# %%
with sns.axes_style("whitegrid"):
    a4 = sns.histplot(
        R4['LNk'], kde=True,
        stat="count", kde_kws=dict(cut=2),
        alpha=.4, edgecolor=(1, 1, 1, .4), bins=int(180/5), line_kws = {'linewidth': 3}, color="red"
)
a4.set_xlabel("Логарифм проницаемости", fontsize = 15, family='Arial')
a4.set_ylabel("Частота", fontsize = 15, family='Arial')
sns.set_theme(rc={'figure.figsize':(10,5)})
a4.set(xlim=(0, None))
a4.set_title('R4', fontsize = 18)
sns.set(font_scale = 1.5)
